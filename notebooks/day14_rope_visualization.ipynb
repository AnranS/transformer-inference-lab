# %% [markdown]
# # Day 14：RoPE 可视化
#
# 对应 [`docs/day14-15.md`](../docs/day14-15.md) 的任务 3。
#
# 第 3 节那张「三条线重合」的图是整个 notebook 的重点——
# 以后忘了 RoPE 是干什么的，看那张图就想起来了。

# %% [markdown]
# ## 1. 频率衰减
#
# 画 `θ_i` 随 `i` 的曲线（对数纵轴），标出各自的周期。

# %%
# 画 theta_i 曲线

# %% [markdown]
# ## 2. 单个平面的旋转
#
# 固定一个平面，画位置 0～20 时向量在单位圆上的移动。

# %%
# 画单位圆上的旋转轨迹

# %% [markdown]
# ## 3. 相对位置不变性（本节重点）
#
# 画 `<R_m q, R_n k>` 关于 `n - m` 的曲线，叠加三条不同 `m` 起点的线。
#
# **它们应该完全重合**——这就是「相对位置」的含义。

# %%
# 三条不同 m 起点的曲线，验证是否重合

# %% [markdown]
# ## 4. `rope_theta` 的影响
#
# `base=10000` vs `500000`，对比最低频的周期长度。
#
# 这解释了长上下文模型为什么要调大 base。

# %%
# 对比两种 base 下最低频平面的周期
